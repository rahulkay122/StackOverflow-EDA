# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Setting View paremeters
pd.options.display.width= 0
pd.set_option('display.max.columns', 100)

# %%
df= pd.read_csv("D:\DA\DA_Projects\EDA\stack-overflow-developer-survey-2023\survey_results_public.csv")

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df.set_index('ResponseId', inplace= True)

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
df.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %%
df= df[[#'Q120',
   'MainBranch', 'Age', 'Employment', 'RemoteWork', 'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
   'Country', #'LearnCodeCoursesCert', 
   'YearsCode', 'YearsCodePro', 'DevType',
   'OrgSize', 'PurchaseInfluence', #'TechList', 'BuyNewTool',
   'Currency', 'CompTotal', 
   #'LanguageHaveWorkedWith','LanguageWantToWorkWith', 'DatabaseHaveWorkedWith','DatabaseWantToWorkWith', 
   'PlatformHaveWorkedWith', #'PlatformWantToWorkWith', 
   'WebframeHaveWorkedWith', #'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith','MiscTechWantToWorkWith', 
   'ToolsTechHaveWorkedWith',
   #'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
   #'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
   #'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
   #'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
   #'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
   #'AISearchWantToWorkWith', 'AIDevHaveWorkedWith', 'AIDevWantToWorkWith',
    #'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq', 'SOComm',
    #'SOAI', 'AISelect', 'AISent', 'AIAcc', 'AIBen',
    'AIToolInterested in Using', 'AIToolCurrently Using',
    #'AIToolNot interested in Using', 'AINextVery different',
    #'AINextNeither different nor similar', 'AINextSomewhat similar',
    #'AINextVery similar', 'AINextSomewhat different', 'TBranch', 'ICorPM',
    'WorkExp',
    #'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
    #'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Knowledge_8',
    #'Frequency_1', 'Frequency_2', 'Frequency_3', 'TimeSearching',
    #'TimeAnswering',
    'ProfessionalTech', 'Industry', #'SurveyLength','SurveyEase',
    'ConvertedCompYearly']].copy()

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1                            None of these  18-24 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  45-54 years old
# 4           I am a developer by profession  25-34 years old
# 5           I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# 2                                         Remote
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89184 entries, 1 to 89184
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   MainBranch                 89184 non-null  object
#  1   Age                        89184 non-null  object
#  2   Employment                 87898 non-null  object
#  3   RemoteWork                 73810 non-null  object
#  4   CodingActivities           73764 non-null  object
#  5   EdLevel                    87973 non-null  object
#  6   LearnCode                  87663 non-null  object
#  7   LearnCodeOnline            70084 non-null  object
#  8   Country                    87973 non-null  object
#  9   YearsCode                  87435 non-null  object
#  10  YearsCodePro               66136 non-null  object
#  11  DevType                    76872 non-null  object
#  12  OrgSize                    65043 non-null  object
# ...

# %%
df.rename(columns={'Age': 'Age Group'}, inplace=True)

# %%
df.WorkExp.dropna(inplace=True)

# %%
df.head()
# Out:
#                                 MainBranch        Age Group  \
# ResponseId
# 1                            None of these  18-24 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  45-54 years old
# 4           I am a developer by profession  25-34 years old
# 5           I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# 2                                         Remote
# ...

# %%
df[df.isna()]
# Out:
#            MainBranch Age Group Employment RemoteWork CodingActivities  \
# ResponseId
# 1                 NaN       NaN        NaN        NaN              NaN
# 2                 NaN       NaN        NaN        NaN              NaN
# 3                 NaN       NaN        NaN        NaN              NaN
# 4                 NaN       NaN        NaN        NaN              NaN
# 5                 NaN       NaN        NaN        NaN              NaN
# ...               ...       ...        ...        ...              ...
# 89180             NaN       NaN        NaN        NaN              NaN
# 89181             NaN       NaN        NaN        NaN              NaN
# 89182             NaN       NaN        NaN        NaN              NaN
# 89183             NaN       NaN        NaN        NaN              NaN
# 89184             NaN       NaN        NaN        NaN              NaN
#
#            EdLevel LearnCode LearnCodeOnline Country YearsCode YearsCodePro  \
# ResponseId
# ...

# %%
df.Country.value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
# New dataframe showing responses from India 

df2= df[df['Country']=='India'].copy()

# %%
df2.to_csv("StackOverflowIndia.csv")

# %%
df2['Age Group']= df2['Age Group'].str.split(pat='years old').str[0]
df2['OrgSize']= df2['OrgSize'].str.split(pat="employees").str[0]

# %%
df2.reset_index(inplace=True)

# %%
df2.head()
# Out:
#    ResponseId                      MainBranch Age Group  \
# 0          10  I am a developer by profession    25-34
# 1          67  I am a developer by profession    25-34
# 2          79  I am a developer by profession    18-24
# 3          83  I am a developer by profession    25-34
# 4          86  I am a developer by profession    25-34
#
#                            Employment                            RemoteWork  \
# 0  Not employed, but looking for work                                   NaN
# 1                 Employed, full-time  Hybrid (some remote, some in-person)
# 2                 Employed, full-time                                Remote
# 3                 Employed, full-time  Hybrid (some remote, some in-person)
# 4                 Employed, full-time                             In-person
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# ...

# %%
#df2.YearsCode.astype('int')
#df2.WorkExp.astype('int')

# %%
df2.YearsCode.value_counts()
# Out:
# YearsCode
# 3                     640
# 4                     525
# 5                     523
# 6                     460
# 2                     437
# 10                    384
# 7                     356
# 8                     330
# 1                     221
# 12                    220
# 9                     196
# 15                    185
# Less than 1 year      169
# 14                    139
# 11                    132
# 13                    123
# 16                     82
# 20                     81
# 17                     68
# 18                     58
# 25                     37
# 22                     30
# 19                     23
# 23                     22
# 30                     15
# 24                     15
# 21                     12
# 27                      9
# 26                      8
# 29                      5
# 28                      5
# 33                      5
# 35                      3
# 32                      3
# More than 50 years      3
# ...

# %%
df2.loc[ df2['YearsCode'] == "Less than 1 year", 'YearsCode'] = "0"
df2.loc[ df2['YearsCode'] == "More than 50 years", 'YearsCode'] = "<50"

# %%
df2.sort_values(by= 'YearsCode', ascending=True).head()
# Out:
#       ResponseId             MainBranch  Age Group  \
# 1901       37074  I am learning to code  Under 18
# 5571       88788  I am learning to code     18-24
# 4281       73055  I am learning to code     25-34
# 3180       56806  I am learning to code     18-24
# 3179       56733  I am learning to code     18-24
#
#                               Employment RemoteWork CodingActivities  \
# 1901                  Student, full-time        NaN              NaN
# 5571                  Student, full-time        NaN              NaN
# 4281  Not employed, but looking for work        NaN              NaN
# 3180                  Student, full-time        NaN              NaN
# 3179                  Student, full-time        NaN              NaN
#
#                                                 EdLevel  \
# 1901  Secondary school (e.g. American high school, G...
# 5571  Some college/university study without earning ...
# 4281                                     Something else
# ...

# %%
df2.shape
# Out:
# (5625, 26)

# %%
#replacing null values with a dictionary

df2[df2['WorkExp'].isna()].fillna({
    'WorkExp': df2.WorkExp.mean(),
    'Industry': 'Other',
    'Currency': 'INR/Indian rupee',     
    'WebframeHaveWorkedWith': 'Other',
    'Industry': 'Other'})


df2['WebframeHaveWorkedWith'].fillna(method= 'ffill')
# Out:
# C:\Users\redhu\AppData\Local\Temp\ipykernel_19028\522519925.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2['WebframeHaveWorkedWith'].fillna(method= 'ffill')
# 0                      Angular;Express;NestJS;React
# 1                      Angular;Express;NestJS;React
# 2                           Angular;Next.js;Node.js
# 3                           Angular;Next.js;Node.js
# 4                               Angular;Spring Boot
#                            ...
# 5620                            Flask;Next.js;React
# 5621                                          Flask
# 5622     Django;Express;FastAPI;Flask;Node.js;React
# 5623    Angular;Django;Express;NestJS;Node.js;React
# 5624                   Express;Node.js;React;Svelte
# Name: WebframeHaveWorkedWith, Length: 5625, dtype: object

# %%
df2.drop(columns={'ProfessionalTech', 'AIToolCurrently Using', 'AIToolInterested in Using'}, inplace= True)

# %%
df2.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age Group', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'Country', 'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize',
#        'PurchaseInfluence', 'Currency', 'CompTotal', 'PlatformHaveWorkedWith',
#        'WebframeHaveWorkedWith', 'ToolsTechHaveWorkedWith', 'WorkExp',
#        'Industry', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5625 entries, 0 to 5624
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ResponseId               5625 non-null   int64
#  1   MainBranch               5625 non-null   object
#  2   Age Group                5625 non-null   object
#  3   Employment               5612 non-null   object
#  4   RemoteWork               4147 non-null   object
#  5   CodingActivities         4140 non-null   object
#  6   EdLevel                  5625 non-null   object
#  7   LearnCode                5588 non-null   object
#  8   LearnCodeOnline          4415 non-null   object
#  9   Country                  5625 non-null   object
#  10  YearsCode                5533 non-null   object
#  11  YearsCodePro             3643 non-null   object
#  12  DevType                  4493 non-null   object
#  13  OrgSize                  3660 non-null   object
# ...

# %%
df2.head()
# Out:
#    ResponseId                      MainBranch Age Group  \
# 0          10  I am a developer by profession    25-34
# 1          67  I am a developer by profession    25-34
# 2          79  I am a developer by profession    18-24
# 3          83  I am a developer by profession    25-34
# 4          86  I am a developer by profession    25-34
#
#                            Employment                            RemoteWork  \
# 0  Not employed, but looking for work                                   NaN
# 1                 Employed, full-time  Hybrid (some remote, some in-person)
# 2                 Employed, full-time                                Remote
# 3                 Employed, full-time  Hybrid (some remote, some in-person)
# 4                 Employed, full-time                             In-person
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# ...

# %%
#Cleaning the Currency Column

df2.Currency= df2.Currency.str.replace(pat='INR\tIndian rupee', repl= 'INR')
df2.Currency = df2.Currency.fillna('INR')

# %%
df2.query('Currency != "INR"')
# Out:
#       ResponseId                      MainBranch Age Group  \
# 15           248  I am a developer by profession    25-34
# 17           271  I am a developer by profession    25-34
# 87          1043  I am a developer by profession    18-24
# 111         1562  I am a developer by profession    18-24
# 112         1566  I am a developer by profession    25-34
# ...          ...                             ...       ...
# 5264       85158  I am a developer by profession    18-24
# 5301       85510  I am a developer by profession    35-44
# 5350       85834  I am a developer by profession    25-34
# 5354       85854  I am a developer by profession    18-24
# 5560       88120  I am a developer by profession    18-24
#
#                                              Employment  \
# 15    Independent contractor, freelancer, or self-em...
# 17                                  Employed, full-time
# 87                                  Employed, full-time
# ...

# %%
# New dataframe that without any NA values
df3= df2.dropna().copy()

# %% [markdown]
# # Cleaning df3 and setting datatypes

# %%
df3.MainBranch.value_counts()
# Out:
# MainBranch
# I am a developer by profession                                                           742
# I am not primarily a developer, but I write code sometimes as part of my work/studies     26
# Name: count, dtype: int64

# %%
df2.YearsCodePro= df2.YearsCodePro.str.replace('Less than 1 year', '0')

# %%
df3.MainBranch= df3.MainBranch.str.replace('I am a developer by profession' ,'Developer')
df3.MainBranch= df3.MainBranch.str.replace('I am not primarily a developer, but I write code sometimes as part of my work/studies', 'Not a Developer')

df3.MainBranch= df3.MainBranch.astype(dtype= 'category')

# %%
df3.MainBranch
# Out:
# 6       Developer
# 12      Developer
# 18      Developer
# 22      Developer
# 25      Developer
#           ...
# 5598    Developer
# 5602    Developer
# 5606    Developer
# 5610    Developer
# 5618    Developer
# Name: MainBranch, Length: 768, dtype: category
# Categories (2, object): ['Developer', 'Not a Developer']

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 768 entries, 6 to 5618
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ResponseId               768 non-null    int64
#  1   MainBranch               768 non-null    category
#  2   Age Group                768 non-null    object
#  3   Employment               768 non-null    object
#  4   RemoteWork               768 non-null    object
#  5   CodingActivities         768 non-null    object
#  6   EdLevel                  768 non-null    object
#  7   LearnCode                768 non-null    object
#  8   LearnCodeOnline          768 non-null    object
#  9   Country                  768 non-null    object
#  10  YearsCode                768 non-null    object
#  11  YearsCodePro             768 non-null    object
#  12  DevType                  768 non-null    object
#  13  OrgSize                  768 non-null    object
# ...

# %%
#Checking the number of unique values in the column
df3.RemoteWork.value_counts()
# Out:
# RemoteWork
# Remote                                  301
# Hybrid (some remote, some in-person)    296
# In-person                               171
# Name: count, dtype: int64

# %%
df3.RemoteWork = df3.RemoteWork.str.replace('Hybrid (some remote, some in-person)', 'Hybrid')
df3.RemoteWork = df3.RemoteWork.astype(dtype= 'category')

# %%
df3.describe()
# Out:
#          ResponseId     CompTotal     WorkExp  ConvertedCompYearly
# count    768.000000  7.680000e+02  768.000000           768.000000
# mean   47010.097656  2.096767e+06    6.229167         26721.795573
# std    26704.581557  2.027848e+06    4.976302         26284.547069
# min      128.000000  5.000000e+01    0.000000             1.000000
# 25%    21258.500000  7.180000e+05    2.000000          9445.000000
# 50%    50643.000000  1.600000e+06    5.000000         19884.000000
# 75%    71649.250000  2.800000e+06    9.000000         36351.000000
# max    89106.000000  2.000000e+07   30.000000        242338.000000

# %%
df3= df3.reset_index()

# %%
df3.columns
# Out:
# Index(['index', 'ResponseId', 'MainBranch', 'Age Group', 'Employment',
#        'RemoteWork', 'CodingActivities', 'EdLevel', 'LearnCode',
#        'LearnCodeOnline', 'Country', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'Currency', 'CompTotal',
#        'PlatformHaveWorkedWith', 'WebframeHaveWorkedWith',
#        'ToolsTechHaveWorkedWith', 'WorkExp', 'Industry',
#        'ConvertedCompYearly'],
#       dtype='object')

# %%
df3= df3.drop(columns= {'index'})

# %%
df3.head()
# Out:
#    ResponseId MainBranch Age Group                               Employment  \
# 0         128  Developer    25-34                       Employed, full-time
# 1         210  Developer    18-24                       Employed, full-time
# 2         272  Developer    18-24                       Employed, full-time
# 3         315  Developer    25-34   Employed, full-time;Employed, part-time
# 4         381  Developer    25-34                       Employed, full-time
#
#   RemoteWork                                   CodingActivities  \
# 0     Remote           Hobby;Contribute to open-source projects
# 1     Remote  Hobby;Contribute to open-source projects;Profe...
# 2  In-person  Hobby;Contribute to open-source projects;Freel...
# 3     Hybrid  Hobby;Contribute to open-source projects;Boots...
# 4     Remote  Hobby;Contribute to open-source projects;Profe...
#
#                                            EdLevel  \
# 0     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %% [markdown]
# # Answering questions

# %% [markdown]
# - Who is the highest paid employee in India?
# - How much does remote working matter to emplyees?
# - How much does coding experience affect compensation?
# - Does a master's degree give you any significant advantage?

# %%
# Who is the highest paid employee in India? 

df3[df3.CompTotal== df3.CompTotal.max()]
# Out:
#      ResponseId MainBranch Age Group           Employment RemoteWork  \
# 164       17522  Developer    25-34   Employed, full-time  In-person
#
#                                       CodingActivities  \
# 164  Contribute to open-source projects;Bootstrappi...
#
#                                           EdLevel  \
# 164  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                              LearnCode  \
# 164  Books / Physical media;Colleague;Hackathons (v...
#
#                                        LearnCodeOnline Country YearsCode  \
# 164  Formal documentation provided by the owner of ...   India        15
#
#     YearsCodePro              DevType          OrgSize  \
# 164           10  Engineering manager  1,000 to 4,999
#
#                     PurchaseInfluence Currency   CompTotal  \
# 164  I have a great deal of influence      INR  20000000.0
#
#                                 PlatformHaveWorkedWith  \
# ...

# %%
# Alternate way of finding max in the column and its correspnding row
# df3.nlargest(1, 'CompTotal')

# %%
df3.ResponseId.value_counts().sum()
# Out:
# 768

# %% [markdown]
# What percent of people are working remotely?

# %%
df3[df3.RemoteWork=='Remote']
# Out:
#      ResponseId MainBranch Age Group  \
# 0           128  Developer    25-34
# 1           210  Developer    18-24
# 4           381  Developer    25-34
# 6           464  Developer    25-34
# 10          807  Developer    25-34
# ..          ...        ...       ...
# 759       88864  Developer    25-34
# 762       88937  Developer    25-34
# 763       88956  Developer    25-34
# 766       89035  Developer    25-34
# 767       89106  Developer    18-24
#
#                                             Employment RemoteWork  \
# 0                                  Employed, full-time     Remote
# 1                                  Employed, full-time     Remote
# 4                                  Employed, full-time     Remote
# 6                                  Employed, full-time     Remote
# 10   Employed, full-time;Independent contractor, fr...     Remote
# ..                                                 ...        ...
# ...

# %%
df3.groupby('RemoteWork')['ResponseId'].count()
# Out:
# C:\Users\redhu\AppData\Local\Temp\ipykernel_19028\3772972952.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df3.groupby('RemoteWork')['ResponseId'].count()
# RemoteWork
# Hybrid       296
# In-person    171
# Remote       301
# Name: ResponseId, dtype: int64

# %% [markdown]
# What percentage of professionals prefer remote or hybrid working conditions?

# %%
df3['RemoteWork'].value_counts(normalize=True)*100
# Out:
# RemoteWork
# Remote       39.192708
# Hybrid       38.541667
# In-person    22.265625
# Name: proportion, dtype: float64

# %% [markdown]
# How much does coding experience affect compensation?

# %%
df3.YearsCodePro= df3.YearsCodePro.str.replace('Less than 1 year', '0')

# %%
#Converting YearsCode and YearsCodePro to numeric to calculate mean 

df3['YearsCode']= df3['YearsCode'].astype('float64')
df3['YearsCodePro']= df3['YearsCodePro'].astype('float64')

# %%
df3.dtypes
# Out:
# ResponseId                    int64
# MainBranch                 category
# Age Group                    object
# Employment                   object
# RemoteWork                 category
# CodingActivities             object
# EdLevel                      object
# LearnCode                    object
# LearnCodeOnline              object
# Country                      object
# YearsCode                   float64
# YearsCodePro                float64
# DevType                      object
# OrgSize                      object
# PurchaseInfluence            object
# Currency                     object
# CompTotal                   float64
# PlatformHaveWorkedWith       object
# WebframeHaveWorkedWith       object
# ToolsTechHaveWorkedWith      object
# WorkExp                     float64
# Industry                     object
# ConvertedCompYearly         float64
# dtype: object

# %%
df3['AvgCodeYears']= (df3['YearsCode']+df3['YearsCodePro'])/2

# %%
# alternate method of calculation mean of 'YearsCode' and 'YearsCodePro'

# df3.AvgCodeYears = df[['YearsCode', 'YearsCodePro']].mean()

# %%
df3.AvgCodeYears
# Out:
# 0       6.5
# 1       7.0
# 2       2.5
# 3       3.0
# 4      15.0
#        ...
# 763    17.0
# 764    17.0
# 765     7.0
# 766     6.5
# 767     5.0
# Name: AvgCodeYears, Length: 768, dtype: float64

# %%
df3.CompTotal
# Out:
# 0      1500000.0
# 1      3000000.0
# 2       420000.0
# 3       300000.0
# 4      2200000.0
#          ...
# 763    3600000.0
# 764    4200000.0
# 765    3100000.0
# 766    2600000.0
# 767    1200000.0
# Name: CompTotal, Length: 768, dtype: float64

# %%
df3.groupby('AvgCodeYears')[('CompTotal')].mean().sort_index()
# Out:
# AvgCodeYears
# 1.0     7.175556e+05
# 1.5     6.476000e+05
# 2.0     6.373750e+05
# 2.5     1.069000e+06
# 3.0     1.012673e+06
# 3.5     1.380711e+06
# 4.0     1.403183e+06
# 4.5     1.375026e+06
# 5.0     1.865853e+06
# 5.5     1.322692e+06
# 6.0     1.835190e+06
# 6.5     1.574846e+06
# 7.0     2.276077e+06
# 7.5     1.567697e+06
# 8.0     2.813897e+06
# 8.5     2.402967e+06
# 9.0     2.418913e+06
# 9.5     2.640918e+06
# 10.0    2.897308e+06
# 10.5    2.872727e+06
# 11.0    2.870571e+06
# 11.5    2.990000e+06
# 12.0    3.052895e+06
# 12.5    5.291667e+06
# 13.0    2.388098e+06
# 13.5    3.025004e+06
# 14.0    3.588889e+06
# 14.5    3.105000e+06
# 15.0    2.119000e+06
# 15.5    5.033333e+06
# 16.0    4.355556e+06
# 17.0    3.475000e+06
# 17.5    2.718571e+06
# 18.0    4.836000e+06
# 18.5    1.200000e+07
# 19.0    4.162500e+06
# 19.5    1.466448e+06
# 20.0    5.266667e+06
# 20.5    3.400000e+06
# 21.0    5.000000e+06
# 21.5    3.730000e+06
# 22.0    3.600000e+06
# ...

# %%
df3.groupby('AvgCodeYears')[('ConvertedCompYearly')].mean().sort_index()
# Out:
# AvgCodeYears
# 1.0       8694.555556
# 1.5       7846.800000
# 2.0       7723.000000
# 2.5      12952.848485
# 3.0      12809.345455
# 3.5      16730.026316
# 4.0      17002.250000
# 4.5      16661.000000
# 5.0      25687.750000
# 5.5      16026.846154
# 6.0      22236.809524
# 6.5      24405.807692
# 7.0      27578.948718
# 7.5      22896.421053
# 8.0      34095.689655
# 8.5      30433.700000
# 9.0      29309.608696
# 9.5      31999.705882
# 10.0     35106.423077
# 10.5     34808.545455
# 11.0     34782.500000
# 11.5     36229.428571
# 12.0     40631.210526
# 12.5     64118.583333
# 13.0     34710.368421
# 13.5     36653.666667
# 14.0     43486.111111
# 14.5     37622.750000
# 15.0     25675.750000
# 15.5     60988.333333
# 16.0     52775.777778
# 17.0     42106.250000
# 17.5     37174.428571
# 18.0     58597.200000
# 18.5    145403.000000
# 19.0     50436.666667
# 19.5     17769.000000
# 20.0     63815.666667
# 20.5     41197.500000
# 21.0     60584.000000
# 21.5     45196.000000
# ...

# %% [markdown]
# Does a master's degree give you any significant advantage?

# %%
df3.EdLevel.value_counts()
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          556
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       162
# Some college/university study without earning a degree                                 34
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                          7
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)      6
# Primary/elementary school                                                               2
# Associate degree (A.A., A.S., etc.)                                                     1
# Name: count, dtype: int64

# %%
df3[df3['EdLevel']== 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)'].head(2)
# Out:
#    ResponseId MainBranch Age Group                               Employment  \
# 3         315  Developer    25-34   Employed, full-time;Employed, part-time
# 4         381  Developer    25-34                       Employed, full-time
#
#   RemoteWork                                   CodingActivities  \
# 3     Hybrid  Hobby;Contribute to open-source projects;Boots...
# 4     Remote  Hobby;Contribute to open-source projects;Profe...
#
#                                            EdLevel  \
# 3  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                            LearnCode  \
# 3  Books / Physical media;Colleague;Friend or fam...
# 4  Books / Physical media;Colleague;Online Course...
#
#                                      LearnCodeOnline Country  YearsCode  \
# 3  Formal documentation provided by the owner of ...   India        4.0
# ...

# %%
df3.groupby('EdLevel')[['ConvertedCompYearly', 'CompTotal']]\
    .mean()[1:3]\
    .sort_values('ConvertedCompYearly', ascending= False)
# Out:
#                                                  ConvertedCompYearly  \
# EdLevel
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)         30415.345679
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)            25725.332734
#
#                                                     CompTotal
# EdLevel
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  2.303097e+06
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)     2.085011e+06

# %% [markdown]
# # Visulizations

# %% [markdown]
# Graph showing percentage of people working hybrid or remote

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('bmh')

# %%
plt.rcParams.update(plt.rcParamsDefault)
# %matplotlib inline
plt.style.use('tableau-colorblind10')

# %%
ax= df3['RemoteWork'].value_counts(normalize=True). \
    plot(
        kind= 'bar',
        title= ' Percentage of people working remote/hybrid/Offline',
        rot= 0,
        xlabel= 'Mode of Work',
        ylabel= 'Percentage',
        
        )

# %%
ax =df3.WorkExp.plot(
    kind='hist',
    x= 'WorkExp',
    bins= 30, 
    xlabel= 'WorkExpYears', 
    ylabel= 'TotalComp',
    legend= False
    )

# %%
Dcorr= df3.corr(numeric_only=True)

# %%
sns.heatmap(
    data= Dcorr,
    annot=True,    
    square= True
    )
plt.rcParams['figure.figsize']=(20, 10)

# %%
df3['Age Group'].value_counts().sort_index()
# Out:
# Age Group
# 18-24     243
# 25-34     432
# 35-44      80
# 45-54      13
# Name: count, dtype: int64

# %%
sns.lineplot(data= df3,y='ConvertedCompYearly', x= 'Age Group')
# Out:
# <Axes: xlabel='Age Group', ylabel='ConvertedCompYearly'>

# %%
ax= df3.plot(
    kind= 'scatter',
    title= 'Total Compensation (USD)',
    xlabel= 'Age group',
    ylabel= 'Yearly compensation',
    x='Age Group',
    y='ConvertedCompYearly',
    
    
    )

# %%
ax= sns.pairplot(data= df3,  vars= {'YearsCode', 'YearsCodePro' ,'CompTotal', 'WorkExp', 'AvgCodeYears', } )

# %%
ax= df3.groupby('EdLevel')['ConvertedCompYearly']\
    .mean()[1:3]\
    .plot(
        kind= 'bar',
        xlabel= 'Education Level',
        ylabel= 'Avg Yearly Compensation (USD)',
        title= 'Avg. Yearly compensation: Bachelors vs Masters (In India)',
        
        
        
        rot=0     
        )

# %% [markdown]
# # Observations:
# - The general trend that can be seen is that the salary remarkably increases in the beginning of one's career but then gradually declines as one gains experience.
#
# - In India, a masters graduate earns more than an average undergraduate.
#
# - Professionals who are of ages 25-34 earn more in average.
